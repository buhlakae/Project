# %% [markdown]
# # Systems

# %% [markdown]
# ## Overdamped Systems: $c > c_c$

# %%
# %matplotlib inline
from math import *
import numpy as np
import matplotlib.pyplot as plt


omega = 1
zeta = 1.1



c1 = 1./6
c2 = 2./6
c3 = 2./6
c4 = 1./6
a2 = 1./2
a3 = 1./2
a4 = 1.
b21 = 1./2
b31 = 0.
b32 = 1./2
b41 = 0.
b42 = 0.
b43 = 1.

F_over_m = lambda t:0
fx = lambda t,x,v: v
fv = lambda t,x,v: F_over_m(t)-(2*zeta*omega*fx(t,x,v))-((omega**2)*x)
                              
def rk4_x(ti, xi,vi,dt):
    K1 = fx(ti,xi,vi)
    K2 = fx(ti+a2*dt,xi+b21*K1*dt,vi)
    K3 = fx(ti+a3*dt,xi+b31*K1*dt+b32*K2*dt,vi)
    K4 = fx(ti+a4*dt,xi+b41*K1*dt+b42*K2*dt+b43*K3*dt,vi)   
    xip1 = xi+(c1*K1+c2*K2+c3*K3+c4*K4)*dt
    return xip1
                                
def rk4_v(ti,xi, vi,dt):
    K1 = fv(ti,xi,vi)
    K2 = fv(ti+a2*dt,xi,vi+b21*K1*dt)
    K3 = fv(ti+a3*dt,xi,vi+b31*K1*dt+b32*K2*dt)
    K4 = fv(ti+a4*dt,xi,vi+b41*K1*dt+b42*K2*dt+b43*K3*dt)   
    vip1 = vi+(c1*K1+c2*K2+c3*K3+c4*K4)*dt
    return vip1

ti = 0.0    #initial value for t 
tf = 10    #final value for t
n = 5000


dt = (tf-ti)/n   #step size
t = np.zeros(n+1)
x = np.zeros(n+1)
v = np.zeros(n+1)
x_iv = 0
v_iv = 2.0

t[0] = ti
x[0] = x_iv
v[0] = v_iv

for i in range(1,n+1):
    t[i] = ti + i*dt
    x[i] = rk4_x(t[i-1],x[i-1],v[i-1], dt)
    v[i] = rk4_v(t[i-1],x[i-1],v[i-1], dt)
    

    
fig = plt.figure(figsize=(8,9))
ax1=plt.subplot(211)
plt.plot(t,x,label=" x vs. t ",color="b",linewidth="2.0")
plt.xlabel("t (s)")
plt.ylabel("x (m)")

ax2=plt.subplot(212, sharex=ax1)
plt.plot(t,v,label=" v vs. t ",color="b",linewidth="2.0")
plt.xlabel("t (s)")
plt.ylabel("v (m/s)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Underdamped Systems: $c < c_c$

# %%
# %matplotlib inline
from math import *
import numpy as np
import matplotlib.pyplot as plt


omega = 1
zeta = 0.1



c1 = 1./6
c2 = 2./6
c3 = 2./6
c4 = 1./6
a2 = 1./2
a3 = 1./2
a4 = 1.
b21 = 1./2
b31 = 0.
b32 = 1./2
b41 = 0.
b42 = 0.
b43 = 1.

F_over_m = lambda t:0
fx = lambda t,x,v: v
fv = lambda t,x,v: F_over_m(t)-(2*zeta*omega*fx(t,x,v))-((omega**2)*x)

def rk4_x(ti, xi,vi,dt):
    K1 = fx(ti,xi,vi)
    K2 = fx(ti+a2*dt,xi+b21*K1*dt,vi)
    K3 = fx(ti+a3*dt,xi+b31*K1*dt+b32*K2*dt,vi)
    K4 = fx(ti+a4*dt,xi+b41*K1*dt+b42*K2*dt+b43*K3*dt,vi)   
    xip1 = xi+(c1*K1+c2*K2+c3*K3+c4*K4)*dt
    return xip1
                                
def rk4_v(ti,xi, vi,dt):
    K1 = fv(ti,xi,vi)
    K2 = fv(ti+a2*dt,xi,vi+b21*K1*dt)
    K3 = fv(ti+a3*dt,xi,vi+b31*K1*dt+b32*K2*dt)
    K4 = fv(ti+a4*dt,xi,vi+b41*K1*dt+b42*K2*dt+b43*K3*dt)   
    vip1 = vi+(c1*K1+c2*K2+c3*K3+c4*K4)*dt
    return vip1

ti = 0.0    #initial value for t 
tf = 10    #final value for t
n = 5000


dt = (tf-ti)/n   #step size
t = np.zeros(n+1)
x = np.zeros(n+1)
v = np.zeros(n+1)
x_iv = 0
v_iv = 2.0

t[0] = ti
x[0] = x_iv
v[0] = v_iv

for i in range(1,n+1):
    t[i] = ti + i*dt
    x[i] = rk4_x(t[i-1],x[i-1],v[i-1], dt)
    v[i] = rk4_v(t[i-1],x[i-1],v[i-1], dt)
    

    
fig = plt.figure(figsize=(8,9))
ax1=plt.subplot(211)
plt.plot(t,x,label=" x vs. t ",color="b",linewidth="2.0")
plt.xlabel("t (s)")
plt.ylabel("x (m)")

ax2=plt.subplot(212, sharex=ax1)
plt.plot(t,v,label=" v vs. t ",color="b",linewidth="2.0")
plt.xlabel("t (s)")
plt.ylabel("v (m/s)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Critically Damped: $c = c_c$

# %%
# %matplotlib inline
from math import *
import numpy as np
import matplotlib.pyplot as plt


omega = 1
zeta = 1



c1 = 1./6
c2 = 2./6
c3 = 2./6
c4 = 1./6
a2 = 1./2
a3 = 1./2
a4 = 1.
b21 = 1./2
b31 = 0.
b32 = 1./2
b41 = 0.
b42 = 0.
b43 = 1.

F_over_m = lambda t:0
fx = lambda t,x,v: v
fv = lambda t,x,v: F_over_m(t)-(2*zeta*omega*fx(t,x,v))-((omega**2)*x)

def rk4_x(ti, xi,vi,dt):
    K1 = fx(ti,xi,vi)
    K2 = fx(ti+a2*dt,xi+b21*K1*dt,vi)
    K3 = fx(ti+a3*dt,xi+b31*K1*dt+b32*K2*dt,vi)
    K4 = fx(ti+a4*dt,xi+b41*K1*dt+b42*K2*dt+b43*K3*dt,vi)   
    xip1 = xi+(c1*K1+c2*K2+c3*K3+c4*K4)*dt
    return xip1
                                
def rk4_v(ti,xi, vi,dt):
    K1 = fv(ti,xi,vi)
    K2 = fv(ti+a2*dt,xi,vi+b21*K1*dt)
    K3 = fv(ti+a3*dt,xi,vi+b31*K1*dt+b32*K2*dt)
    K4 = fv(ti+a4*dt,xi,vi+b41*K1*dt+b42*K2*dt+b43*K3*dt)   
    vip1 = vi+(c1*K1+c2*K2+c3*K3+c4*K4)*dt
    return vip1

ti = 0.0    #initial value for t 
tf = 10    #final value for t
n = 5000


dt = (tf-ti)/n   #step size
t = np.zeros(n+1)
x = np.zeros(n+1)
v = np.zeros(n+1)
x_iv = 0
v_iv = 2.0

t[0] = ti
x[0] = x_iv
v[0] = v_iv

for i in range(1,n+1):
    t[i] = ti + i*dt
    x[i] = rk4_x(t[i-1],x[i-1],v[i-1], dt)
    v[i] = rk4_v(t[i-1],x[i-1],v[i-1], dt)
    
fig = plt.figure(figsize=(8,9))
ax1=plt.subplot(211)
plt.plot(t,x,label=" x vs. t ",color="b",linewidth="2.0")
plt.xlabel("t (s)")
plt.ylabel("x (m)")

ax2=plt.subplot(212, sharex=ax1)
plt.plot(t,v,label=" v vs. t ",color="b",linewidth="2.0")
plt.xlabel("t (s)")
plt.ylabel("v (m/s)")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Tests

# %%
# %matplotlib inline
from math import *
import numpy as np
import matplotlib.pyplot as plt


omega = 1
zeta = 1.1


c1 = 1./6
c2 = 2./6
c3 = 2./6
c4 = 1./6
a2 = 1./2
a3 = 1./2
a4 = 1.
b21 = 1./2
b31 = 0.
b32 = 1./2
b41 = 0.
b42 = 0.
b43 = 1.

F_over_m = lambda t:5
fx = lambda t,x,v: v
fv = lambda t,x,v: F_over_m(t)-(2*zeta*omega*fx(t,x,v))-((omega**2)*x)
                              
def rk4_x(ti, xi,vi,dt):
    K1 = fx(ti,xi,vi)
    K2 = fx(ti+a2*dt,xi+b21*K1*dt,vi)
    K3 = fx(ti+a3*dt,xi+b31*K1*dt+b32*K2*dt,vi)
    K4 = fx(ti+a4*dt,xi+b41*K1*dt+b42*K2*dt+b43*K3*dt,vi)   
    xip1 = xi+(c1*K1+c2*K2+c3*K3+c4*K4)*dt
    return xip1
                                
def rk4_v(ti,xi, vi,dt):
    K1 = fv(ti,xi,vi)
    K2 = fv(ti+a2*dt,xi,vi+b21*K1*dt)
    K3 = fv(ti+a3*dt,xi,vi+b31*K1*dt+b32*K2*dt)
    K4 = fv(ti+a4*dt,xi,vi+b41*K1*dt+b42*K2*dt+b43*K3*dt)   
    vip1 = vi+(c1*K1+c2*K2+c3*K3+c4*K4)*dt
    return vip1

ti = 0.0    #initial value for t 
tf = 10    #final value for t
n = 5000


dt = (tf-ti)/n   #step size
t = np.zeros(n+1)
x = np.zeros(n+1)
v = np.zeros(n+1)
x_iv = 0
v_iv = 2.0

t[0] = ti
x[0] = x_iv
v[0] = v_iv

for i in range(1,n+1):
    t[i] = ti + i*dt
    x[i] = rk4_x(t[i-1],x[i-1],v[i-1], dt)
    v[i] = rk4_v(t[i-1],x[i-1],v[i-1], dt)
    

    
fig = plt.figure(figsize=(8,9))
ax1=plt.subplot(211)
plt.plot(t,x,label=" x vs. t ",color="b",linewidth="2.0")
plt.xlabel("t (s)")
plt.ylabel("x (m)")

ax2=plt.subplot(212, sharex=ax1)
plt.plot(t,v,label=" v vs. t ",color="b",linewidth="2.0")
plt.xlabel("t (s)")
plt.ylabel("v (m/s)")

plt.tight_layout()
plt.show()

# %%
# %matplotlib inline
from math import *
import numpy as np
import matplotlib.pyplot as plt



omega = 1
zeta = 1.1



c1 = 1./6
c2 = 2./6
c3 = 2./6
c4 = 1./6
a2 = 1./2
a3 = 1./2
a4 = 1.
b21 = 1./2
b31 = 0.
b32 = 1./2
b41 = 0.
b42 = 0.
b43 = 1.

F_over_m = lambda t:sin(t)
fx = lambda t,x,v: v
fv = lambda t,x,v: F_over_m(t)-(2*zeta*omega*fx(t,x,v))-((omega**2)*x)
                              
def rk4_x(ti, xi,vi,dt):
    K1 = fx(ti,xi,vi)
    K2 = fx(ti+a2*dt,xi+b21*K1*dt,vi)
    K3 = fx(ti+a3*dt,xi+b31*K1*dt+b32*K2*dt,vi)
    K4 = fx(ti+a4*dt,xi+b41*K1*dt+b42*K2*dt+b43*K3*dt,vi)   
    xip1 = xi+(c1*K1+c2*K2+c3*K3+c4*K4)*dt
    return xip1
                                
def rk4_v(ti,xi, vi,dt):
    K1 = fv(ti,xi,vi)
    K2 = fv(ti+a2*dt,xi,vi+b21*K1*dt)
    K3 = fv(ti+a3*dt,xi,vi+b31*K1*dt+b32*K2*dt)
    K4 = fv(ti+a4*dt,xi,vi+b41*K1*dt+b42*K2*dt+b43*K3*dt)   
    vip1 = vi+(c1*K1+c2*K2+c3*K3+c4*K4)*dt
    return vip1

ti = 0.0    #initial value for t 
tf = 10    #final value for t
n = 5000


dt = (tf-ti)/n   #step size
t = np.zeros(n+1)
x = np.zeros(n+1)
v = np.zeros(n+1)
x_iv = 0
v_iv = 2.0

t[0] = ti
x[0] = x_iv
v[0] = v_iv

for i in range(1,n+1):
    t[i] = ti + i*dt
    x[i] = rk4_x(t[i-1],x[i-1],v[i-1], dt)
    v[i] = rk4_v(t[i-1],x[i-1],v[i-1], dt)
    

    
fig = plt.figure(figsize=(8,9))
ax1=plt.subplot(211)
plt.plot(t,x,label=" x vs. t ",color="b",linewidth="2.0")
plt.xlabel("t (s)")
plt.ylabel("x (m)")

ax2=plt.subplot(212, sharex=ax1)
plt.plot(t,v,label=" v vs. t ",color="b",linewidth="2.0")
plt.xlabel("t (s)")
plt.ylabel("v (m/s)")

plt.tight_layout()
plt.show()

# %%
# %matplotlib inline
from math import *
import numpy as np
import matplotlib.pyplot as plt

A1 = 1


omega = 1
zeta = 1.1



c1 = 1./6
c2 = 2./6
c3 = 2./6
c4 = 1./6
a2 = 1./2
a3 = 1./2
a4 = 1.
b21 = 1./2
b31 = 0.
b32 = 1./2
b41 = 0.
b42 = 0.
b43 = 1.

F_over_m = lambda t:t**2
fx = lambda t,x,v: v
fv = lambda t,x,v: F_over_m(t)-(2*zeta*omega*fx(t,x,v))-((omega**2)*x)
                              
def rk4_x(ti, xi,vi,dt):
    K1 = fx(ti,xi,vi)
    K2 = fx(ti+a2*dt,xi+b21*K1*dt,vi)
    K3 = fx(ti+a3*dt,xi+b31*K1*dt+b32*K2*dt,vi)
    K4 = fx(ti+a4*dt,xi+b41*K1*dt+b42*K2*dt+b43*K3*dt,vi)   
    xip1 = xi+(c1*K1+c2*K2+c3*K3+c4*K4)*dt
    return xip1
                                
def rk4_v(ti,xi, vi,dt):
    K1 = fv(ti,xi,vi)
    K2 = fv(ti+a2*dt,xi,vi+b21*K1*dt)
    K3 = fv(ti+a3*dt,xi,vi+b31*K1*dt+b32*K2*dt)
    K4 = fv(ti+a4*dt,xi,vi+b41*K1*dt+b42*K2*dt+b43*K3*dt)   
    vip1 = vi+(c1*K1+c2*K2+c3*K3+c4*K4)*dt
    return vip1

ti = 0.0    #initial value for t 
tf = 10    #final value for t
n = 5000


dt = (tf-ti)/n   #step size
t = np.zeros(n+1)
x = np.zeros(n+1)
v = np.zeros(n+1)
x_iv = 0
v_iv = 2.0

t[0] = ti
x[0] = x_iv
v[0] = v_iv

for i in range(1,n+1):
    t[i] = ti + i*dt
    x[i] = rk4_x(t[i-1],x[i-1],v[i-1], dt)
    v[i] = rk4_v(t[i-1],x[i-1],v[i-1], dt)
    

    
fig = plt.figure(figsize=(8,9))
ax1=plt.subplot(211)
plt.plot(t,x,label=" x vs. t ",color="b",linewidth="2.0")
plt.xlabel("t (s)")
plt.ylabel("x (m)")

ax2=plt.subplot(212, sharex=ax1)
plt.plot(t,v,label=" v vs. t ",color="b",linewidth="2.0")
plt.xlabel("t (s)")
plt.ylabel("v (m/s)")

plt.tight_layout()
plt.show()

# %% [markdown]
# From these three tests with three different f(t)/m variables, show how imporatnt the f(t)/m function is to the situation. These functions can indivually represent a different situation realistically. For the first graph f(t)/m is a constant and as for the result the intial values quickly degrade. For the f(t)/m = sin(t), the x/t graph shows a sin wave and the v/t shows a cos graph. It is a cos graph because the the derivation of sin is cos.

# %% [markdown]
# # Part 5

# %% [markdown]
# ## Overdamped

# %%
# %matplotlib inline
from math import *
import numpy as np
import matplotlib.pyplot as plt


omega = 1
zeta = 1.1
A = 5


c1 = 1./6
c2 = 2./6
c3 = 2./6
c4 = 1./6
a2 = 1./2
a3 = 1./2
a4 = 1.
b21 = 1./2
b31 = 0.
b32 = 1./2
b41 = 0.
b42 = 0.
b43 = 1.

F_over_m = lambda t:A*cos(omega*t)
fx = lambda t,x,v: v
fv = lambda t,x,v: F_over_m(t)-(2*zeta*omega*fx(t,x,v))-((omega**2)*x)
                              
def rk4_x(ti, xi,vi,dt):
    K1 = fx(ti,xi,vi)
    K2 = fx(ti+a2*dt,xi+b21*K1*dt,vi)
    K3 = fx(ti+a3*dt,xi+b31*K1*dt+b32*K2*dt,vi)
    K4 = fx(ti+a4*dt,xi+b41*K1*dt+b42*K2*dt+b43*K3*dt,vi)   
    xip1 = xi+(c1*K1+c2*K2+c3*K3+c4*K4)*dt
    return xip1
                                
def rk4_v(ti,xi, vi,dt):
    K1 = fv(ti,xi,vi)
    K2 = fv(ti+a2*dt,xi,vi+b21*K1*dt)
    K3 = fv(ti+a3*dt,xi,vi+b31*K1*dt+b32*K2*dt)
    K4 = fv(ti+a4*dt,xi,vi+b41*K1*dt+b42*K2*dt+b43*K3*dt)   
    vip1 = vi+(c1*K1+c2*K2+c3*K3+c4*K4)*dt
    return vip1

ti = 0.0    #initial value for t 
tf = 10    #final value for t
n = 5000


dt = (tf-ti)/n   #step size
t = np.zeros(n+1)
x = np.zeros(n+1)
v = np.zeros(n+1)
x_iv = 0
v_iv = 2.0

t[0] = ti
x[0] = x_iv
v[0] = v_iv

for i in range(1,n+1):
    t[i] = ti + i*dt
    x[i] = rk4_x(t[i-1],x[i-1],v[i-1], dt)
    v[i] = rk4_v(t[i-1],x[i-1],v[i-1], dt)
    

    
fig = plt.figure(figsize=(8,9))
ax1=plt.subplot(211)
plt.plot(t,x,label=" x vs. t ",color="b",linewidth="2.0")
plt.xlabel("t (s)")
plt.ylabel("x (m)")

ax2=plt.subplot(212, sharex=ax1)
plt.plot(t,v,label=" v vs. t ",color="b",linewidth="2.0")
plt.xlabel("t (s)")
plt.ylabel("v (m/s)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Underdamped Systems

# %%
# %matplotlib inline
from math import *
import numpy as np
import matplotlib.pyplot as plt


omega = 1
zeta = 0.1
A = 5


c1 = 1./6
c2 = 2./6
c3 = 2./6
c4 = 1./6
a2 = 1./2
a3 = 1./2
a4 = 1.
b21 = 1./2
b31 = 0.
b32 = 1./2
b41 = 0.
b42 = 0.
b43 = 1.

F_over_m = lambda t:A*cos(omega*t)
fx = lambda t,x,v: v
fv = lambda t,x,v: F_over_m(t)-(2*zeta*omega*fx(t,x,v))-((omega**2)*x)
                              
def rk4_x(ti, xi,vi,dt):
    K1 = fx(ti,xi,vi)
    K2 = fx(ti+a2*dt,xi+b21*K1*dt,vi)
    K3 = fx(ti+a3*dt,xi+b31*K1*dt+b32*K2*dt,vi)
    K4 = fx(ti+a4*dt,xi+b41*K1*dt+b42*K2*dt+b43*K3*dt,vi)   
    xip1 = xi+(c1*K1+c2*K2+c3*K3+c4*K4)*dt
    return xip1
                                
def rk4_v(ti,xi, vi,dt):
    K1 = fv(ti,xi,vi)
    K2 = fv(ti+a2*dt,xi,vi+b21*K1*dt)
    K3 = fv(ti+a3*dt,xi,vi+b31*K1*dt+b32*K2*dt)
    K4 = fv(ti+a4*dt,xi,vi+b41*K1*dt+b42*K2*dt+b43*K3*dt)   
    vip1 = vi+(c1*K1+c2*K2+c3*K3+c4*K4)*dt
    return vip1

ti = 0.0    #initial value for t 
tf = 10    #final value for t
n = 5000


dt = (tf-ti)/n   #step size
t = np.zeros(n+1)
x = np.zeros(n+1)
v = np.zeros(n+1)
x_iv = 0
v_iv = 2.0

t[0] = ti
x[0] = x_iv
v[0] = v_iv

for i in range(1,n+1):
    t[i] = ti + i*dt
    x[i] = rk4_x(t[i-1],x[i-1],v[i-1], dt)
    v[i] = rk4_v(t[i-1],x[i-1],v[i-1], dt)
    

    
fig = plt.figure(figsize=(8,9))
ax1=plt.subplot(211)
plt.plot(t,x,label=" x vs. t ",color="b",linewidth="2.0")
plt.xlabel("t (s)")
plt.ylabel("x (m)")

ax2=plt.subplot(212, sharex=ax1)
plt.plot(t,v,label=" v vs. t ",color="b",linewidth="2.0")
plt.xlabel("t (s)")
plt.ylabel("v (m/s)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Critically Damped

# %%
# %matplotlib inline
from math import *
import numpy as np
import matplotlib.pyplot as plt


omega = 1
zeta = 1.0
A = 5


c1 = 1./6
c2 = 2./6
c3 = 2./6
c4 = 1./6
a2 = 1./2
a3 = 1./2
a4 = 1.
b21 = 1./2
b31 = 0.
b32 = 1./2
b41 = 0.
b42 = 0.
b43 = 1.

F_over_m = lambda t:A*cos(omega*t)
fx = lambda t,x,v: v
fv = lambda t,x,v: F_over_m(t)-(2*zeta*omega*fx(t,x,v))-((omega**2)*x)
                              
def rk4_x(ti, xi,vi,dt):
    K1 = fx(ti,xi,vi)
    K2 = fx(ti+a2*dt,xi+b21*K1*dt,vi)
    K3 = fx(ti+a3*dt,xi+b31*K1*dt+b32*K2*dt,vi)
    K4 = fx(ti+a4*dt,xi+b41*K1*dt+b42*K2*dt+b43*K3*dt,vi)   
    xip1 = xi+(c1*K1+c2*K2+c3*K3+c4*K4)*dt
    return xip1
                                
def rk4_v(ti,xi, vi,dt):
    K1 = fv(ti,xi,vi)
    K2 = fv(ti+a2*dt,xi,vi+b21*K1*dt)
    K3 = fv(ti+a3*dt,xi,vi+b31*K1*dt+b32*K2*dt)
    K4 = fv(ti+a4*dt,xi,vi+b41*K1*dt+b42*K2*dt+b43*K3*dt)   
    vip1 = vi+(c1*K1+c2*K2+c3*K3+c4*K4)*dt
    return vip1

ti = 0.0    #initial value for t 
tf = 10    #final value for t
n = 5000


dt = (tf-ti)/n   #step size
t = np.zeros(n+1)
x = np.zeros(n+1)
v = np.zeros(n+1)
x_iv = 0
v_iv = 2.0

t[0] = ti
x[0] = x_iv
v[0] = v_iv

for i in range(1,n+1):
    t[i] = ti + i*dt
    x[i] = rk4_x(t[i-1],x[i-1],v[i-1], dt)
    v[i] = rk4_v(t[i-1],x[i-1],v[i-1], dt)
    

    
fig = plt.figure(figsize=(8,9))
ax1=plt.subplot(211)
plt.plot(t,x,label=" x vs. t ",color="b",linewidth="2.0")
plt.xlabel("t (s)")
plt.ylabel("x (m)")

ax2=plt.subplot(212, sharex=ax1)
plt.plot(t,v,label=" v vs. t ",color="b",linewidth="2.0")
plt.xlabel("t (s)")
plt.ylabel("v (m/s)")

plt.tight_layout()
plt.show()
